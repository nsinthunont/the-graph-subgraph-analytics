# %%
import requests, json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

subgraph_id = 'QmbHg6vAJRD9ZWz5GTP9oMrfDyetnGTr5KWJBYAq59fm1W'
subgraph_url = 'https://api.thegraph.com/subgraphs/name/audius-infra/audius-network-mainnet'

# %%
# get all the audius's hosts
audius_api_url = 'https://api.audius.co'
response = requests.get(audius_api_url).json()

# select the first host
audius_host_url = response['data'][0]
audius_app_name = 'nsinthunont'

headers = {
  'Accept': 'application/json'
}

# %% [markdown]
# # Get users

# %%
response = requests.get(f'{audius_host_url}/v1/users/search', params={
  'query': 'Brownies',  'app_name': 'nsinthunont'
}, headers = headers)
response.json()
# Out:
# {'data': [{'album_count': 0,
#    'bio': "Makin' moves & keeping you on your toes.\nlinktr.ee/browniesandlemonade",
#    'cover_photo': {'640x': 'https://creatornode.audius.co/ipfs/QmcVZH5C2ygxoVS4ihPBJrkFrS1Ua6YJB5srNtXafPzihZ/640x.jpg',
#     '2000x': 'https://creatornode.audius.co/ipfs/QmcVZH5C2ygxoVS4ihPBJrkFrS1Ua6YJB5srNtXafPzihZ/2000x.jpg'},
#    'followee_count': 25,
#    'follower_count': 23358,
#    'handle': 'TeamBandL',
#    'id': 'nlGNe',
#    'is_verified': True,
#    'location': 'Los Angeles, CA',
#    'name': 'Brownies & Lemonade',
#    'playlist_count': 2,
#    'profile_picture': {'150x150': 'https://creatornode.audius.co/ipfs/QmU9L4beAM96MpiNqqVTZdiDiCRTeBku1AJCh3NXrE5PxV/150x150.jpg',
#     '480x480': 'https://creatornode.audius.co/ipfs/QmU9L4beAM96MpiNqqVTZdiDiCRTeBku1AJCh3NXrE5PxV/480x480.jpg',
#     '1000x1000': 'https://creatornode.audius.co/ipfs/QmU9L4beAM96MpiNqqVTZdiDiCRTeBku1AJCh3NXrE5PxV/1000x1000.jpg'},
#    'repost_count': 5,
#    'track_count': 8},
# ...
